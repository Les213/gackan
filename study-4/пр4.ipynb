# %%
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer

# %%
df = pd.read_csv('vgsales_14.csv')
df
# Out:
#       Rank                                               Name Platform
# 0    10689                 Generator Rex: Agent of Providence      3DS  \
# 1    10856                                      FIFA Street 3       DS
# 2    12101                 Family Trainer: Treasure Adventure      Wii
# 3     2973                                         Shark Tale      GBA
# 4     8504                                     Medieval Games      Wii
# ..     ...                                                ...      ...
# 548   1004                             Star Wars: Starfighter      PS2
# 549  15227  Umineko no Naku Koro ni: Majo to Suiri no Rinb...      PS3
# 550  15993    Shinseiki Evangelion: Battle Orchestra Portable      PSP
# 551   5753                 Cabela's Outdoor Adventures (2009)      Wii
# 552  15887                         GTI Club: Supermini Festa!      Wii
#
#        Year       Genre                     Publisher  NA_Sales  EU_Sales
# ...

# %%
df.where(df['Rank'] == 10856).dropna()
# Out:
#       Rank           Name Platform    Year   Genre        Publisher  NA_Sales
# 1  10856.0  FIFA Street 3       DS  2008.0  Sports  Electronic Arts      0.07  \
#
#    EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 1      0.02       0.0         0.01          0.09

# %%
df = df.replace({'Name' : 'FIFA Street 3'}, 'Bleach')
df
# Out:
#       Rank                                               Name Platform
# 0    10689                 Generator Rex: Agent of Providence      3DS  \
# 1    10856                                             Bleach       DS
# 2    12101                 Family Trainer: Treasure Adventure      Wii
# 3     2973                                         Shark Tale      GBA
# 4     8504                                     Medieval Games      Wii
# ..     ...                                                ...      ...
# 548   1004                             Star Wars: Starfighter      PS2
# 549  15227  Umineko no Naku Koro ni: Majo to Suiri no Rinb...      PS3
# 550  15993    Shinseiki Evangelion: Battle Orchestra Portable      PSP
# 551   5753                 Cabela's Outdoor Adventures (2009)      Wii
# 552  15887                         GTI Club: Supermini Festa!      Wii
#
#        Year       Genre                     Publisher  NA_Sales  EU_Sales
# ...

# %%
simp = SimpleImputer(missing_values=np.nan)
simp = simp.fit(df[['Rank']])

df['Rank'] = simp.transform(df[['Rank']])
df.isnull().mean()*100
# Out:
# Rank            0.000000
# Name            0.000000
# Platform        0.000000
# Year            1.808318
# Genre           0.000000
# Publisher       0.542495
# NA_Sales        0.000000
# EU_Sales        0.000000
# JP_Sales        0.000000
# Other_Sales     0.000000
# Global_Sales    0.000000
# dtype: float64

# %%
df.to_csv('newDF.csv', index=False)
